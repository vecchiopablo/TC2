# %% [markdown]
# # <center> TC2  </center>
# ## <center> Tarea 1 </center>

# %% [markdown]
# # ![circuito.png](attachment:circuito.png)

# %% [markdown]
# ### 1) $V(+)= \frac{V1.R3}{R3 + \frac {1}{SC}}        =>              V(+)= \frac{V1.SCR3}{SCR3 +1}$

# %% [markdown]
# ### $\frac{V1-V(+)}{R1}=\frac{V(+)-V2}{R2}   =>   \frac{V1}{R1}+\frac{V2}{R2} = V(+). \frac{1}{R1}+\frac{1}{R2} => V(+) = \frac{R2.V1+R1.V2}{R1+R2}$

# %% [markdown]
# ### $\frac{V1.SCR3}{SCR3 +1}= \frac{R2.V1+R1.V2}{R1+R2}=>\frac{V2}{V1}=\frac{S-\frac{R2}{C.R1.R3}}{S+\frac{1}{C.R3}}$

# %% [markdown]
# ###  $ =>\omega_o=\frac{1}{C.R3} => \frac{V2}{V1}     => \frac{V2}{V1}=\frac{S-\frac{R2.\omega_o}{R1}}{S+\omega_o}$

# %% [markdown]
# ### $\frac{V2}{V1}(j\omega)=\frac{j\omega-\frac{R2}{R1}.\omega_o}{j\omega+\omega_o}$

# %% [markdown]
# ### $|\frac{V2}{V1}|²= \frac{\omega²+(\frac{R2}{R1}.\omega_o)²}{\omega²+\omega_o²}$

# %% [markdown]
# ### $\phi= arctg(\frac{\omega}{-\frac{R2}{R1}.\omega_o})-arctg(\frac{\omega}{\omega_o})$

# %% [markdown]
# ![polos%20y%20ceros.jpeg](attachment:polos%20y%20ceros.jpeg)
# ###### Para hacer el gráfico y normalizar, tomo $\frac{R2}{R1}=1$ ^ $\omega_o=\frac{1}{C.R3}=1$

# %% [markdown]
# ### 2) $\frac{V2}{V1}=\frac{$-1}{$+1}$

# %% [markdown]
# ### 3)

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.signal as sig
from splane import analyze_sys, pretty_print_bicuad_omegayq

num = np.array([1,-1]) 
den = np.array([1,1])
pretty_print_bicuad_omegayq(num,den)
tarea1 = sig.TransferFunction(num,den)
plt.close('all')
analyze_sys(tarea1, 'TC2-Tarea1-Pablo Vecchio')
# Out:
# $\displaystyle \frac{s +  -1 }{s^2 + s \frac{  1}{  1} +   1^2}$

# %% [markdown]
# ### 4)
# ![ltspice-circuito_electrico.png](attachment:ltspice-circuito_electrico.png)

# %% [markdown]
# ![ltspice-salida.png](attachment:ltspice-salida.png)

# %% [markdown]
# ### 5) Aplicaciones:
# #### Este tipo de circuitos sirve para activar elementos pasivos, por ejemplo, inductores, que pueden ser reeamplazados por capacitores, resistores y operacionales. Claramente, no vamos a poder generar fuerza magnética, pero sí podríamos tener un circuito que responda de la misma manera que un RLC sin necesidad de colocar un inductor real.
